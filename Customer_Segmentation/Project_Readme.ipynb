# %% [markdown]
# ## Task 3: Customer Segmentation Using KMeans Clustering
# ### A Machine Learning Project — Data Science Internship at @ArchTechnologies
#
# ### 📌 Project Overview
#
# This project performs Customer Segmentation using the KMeans Clustering algorithm.
# The goal is to group customers based on their purchasing behavior so businesses can better understand:
#
# Spending patterns
#
# Income groups
#
# Customer buying tendencies
#
# Target marketing opportunities
#
# ### This is a complete end-to-end unsupervised learning project.
#
# 📂 Dataset
#
# The dataset contains key customer attributes such as:
#
# CustomerID
#
# Gender
#
# Age
#
# Annual Income
#
# Spending Score
#
#
# ### 🧹 Data Preprocessing
#
# Steps performed:
#
# Checked for missing values and duplicates
#
# Cleaned and transformed the dataset
#
# Encoded categorical variables
#
# Scaled numerical features using StandardScaler
#
#
# ### 🔍 Exploratory Data Analysis (EDA)
#
# The analysis included:
#
# Gender distribution
#
# Age, income, and spending distributions
#
# Pairplots showing feature relationships
#
# Outlier detection using boxplots
#
# Correlation heatmaps
#
# These steps help understand trends and guide feature selection for clustering.
#
#
# ###  Machine Learning — KMeans Clustering
# Elbow Method
#
# Used to determine the optimal number of clusters by evaluating WCSS.
#
# Model Training
#
# KMeans was applied with the optimal value of K:
#
# Cluster labels were assigned
#
# Centroids were identified
#
# Segments were analyzed and interpreted
#
#
# ### Visualizations
#
# The project includes:
#
# 2D scatter plot (Income vs Spending Score)
#
# 3D visualization (Age, Income, Spending Score)
#
# Cluster distribution bar plots
#
# These visuals help clearly understand the behavior of each customer group.
#
#
# ### Customer Segments Identified
#
# The clustering revealed:
#
# High-income luxury spenders
#
# Budget-conscious shoppers
#
# Mid-range standard customers
#
# High-income careful spenders
#
# Impulsive low-income buyers
#
# Each segment offers business insights for targeted decision-making.
